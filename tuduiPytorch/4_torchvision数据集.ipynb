# %%
import torchvision

train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True)

print(test_set[0])
print(test_set.classes)

img, target = test_set[0]
print(img)
print(target)
print(test_set.classes[target])
img.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (<PIL.Image.Image image mode=RGB size=32x32 at 0x1555E976580>, 3)
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# <PIL.Image.Image image mode=RGB size=32x32 at 0x1555E9765B0>
# 3
# cat

# %%
from torch.utils.tensorboard import SummaryWriter

data_transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor()])

train_set = torchvision.datasets.CIFAR10(root='./data', train=True, transform=data_transform, download=True)
test_set = torchvision.datasets.CIFAR10(root='./data', train=False, transform=data_transform, download=True)

writer = SummaryWriter('p10')
for i in range(10):
    img, label = test_set[i]
    writer.add_image('test_image', img, i)
    
writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
